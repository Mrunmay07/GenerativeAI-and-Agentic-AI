# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.1-8b-instant")

prompts = [{"role":"user","content":"Hello my name is Mrunmay"}]

res = llm.invoke(prompts)
res.content
# Out:
# "Hello Mrunmay, it's nice to meet you. Is there something I can help you with or would you like to chat?"

# %% [markdown]
# ## Manage History

# %%
history = []

while True:
    query = input("User : ")
    if query.lower() in ["exit","quit","bye"]:
        print("Chat ended")
        break

    history.append({"role":"user" , "content":query})
    print("User: ", query)
    
    res = llm.invoke(history)
    history.append({"role":"ai" , "content":res.content})
    print("AI: ", res.content,"\n"  )
# Out:
# User:  Hello
# AI:  Hello. Is there something I can help you with or would you like to chat?
#
# User:  My name is Mrunmay Ukey
# AI:  Hello Mrunmay Ukey, nice to meet you. Is there something on your mind that you'd like to talk about, or are you just looking for some conversation?
#
# User:  What s my name ?
# AI:  Your name is Mrunmay Ukey.
#
# User:
# AI:  Is everything okay? It seems like you trailed off. Do you want to continue our conversation or is there something else I can help you with?
#
# User:
# AI:  It looks like you might have accidentally ended the message. If you're ready to continue, I'm here to chat with you.
#
# Chat ended
