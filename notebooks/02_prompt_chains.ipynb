# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts = [
        {"role":"system" , "content":"You are a MERN developer"},
        {"role":"user" , "content":"Difference between map and filter"},
    ]

res = llm.invoke(prompts)
print(res.content)
# Out:
# As a MERN stack developer, `map` and `filter` are two of the most frequently used and fundamental array methods in JavaScript. They both create new arrays, but their purposes and the way their callback functions work are distinctly different.
#
# Let's break them down:
#
# ---
#
# ## `Array.prototype.map()`
#
# **Purpose:** To **transform** each element in an array and create a new array with the results of that transformation.
#
# **How it works:**
# 1.  It iterates over every element in the original array.
# 2.  For each element, it calls a provided callback function.
# 3.  The callback function performs some operation on the element and **returns a new value**.
# 4.  `map` collects all these returned values into a **new array**.
# 5.  The new array will always have the **same length** as the original array.
#
# **Key Characteristics:**
# *   **Transforms** elements.
# *   Returns a **new array**.
# *   The new array has the **same length** as the original.
# ...

# %% [markdown]
# ## Prompt Templates - Dynamic Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
out = StrOutputParser()

prompts = ChatPromptTemplate.from_messages([
    {"role":"system" , "content":"You are a translator and translate input into {language}"},
    {"role":"user" , "content":"{query}"}
])

## My Self Chain Node
def transform_case(result:str):
    return result.upper()

""" final_prompts = prompts.format_messages(language="Hindi" , query="I love javascript")
res = llm.invoke(final_prompts)
print(res.content) """

""" prompts.invoke({"language":"Hindi" , "query":"I Love you" })
 """
# Out:
# ' prompts.invoke({"language":"Hindi" , "query":"I Love you" })\n '

# %% [markdown]
# ## Chains - Runnables

# %% [markdown]
# Runnables -> functions or data which we can invoke are Runnables in simple language

# %%
""" res = llm.invoke(prompts.invoke({"language":"Hindi" , "query":"I love you"}))
res.content """
# Out:
# 'मैं तुमसे प्यार करता हूँ। (अगर कहने वाला पुरुष है)\nमैं तुमसे प्यार करती हूँ। (अगर कहने वाली महिला है)'

# %%
chains = prompts | llm | out | transform_case
res = chains.invoke({"language":"Hinglish" , "query":"I love you"})
res
# Out:
# 'मैं तुमसे लव करता हूँ (IF A MALE IS SPEAKING)\nमैं तुमसे लव करती हूँ (IF A FEMALE IS SPEAKING)'
