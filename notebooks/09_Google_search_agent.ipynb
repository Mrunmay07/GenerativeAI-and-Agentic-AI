# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools = [search.run],
    system_prompt="You are a agent and can search any question on google",
    checkpointer=MemorySaver()
)

# %%
question = "Who won 2025 womens world cup?"

# %%
response = agent.invoke(
    {"messages":{"role":"user","content":question}},
    {"configurable":{"thread_id":"mayur"}}
    )
response["messages"][-1].content
# Out:
# 'The 2026 edition of **MTV\u202fSplitsvilla (Season\u202fX6)** was won by the pair **Kushal “Gullu” Tanwar and Kaira Anu**. They took home the trophy and the ₹20\u202flakh prize at the grand finale held in May\u202f2026.'
