# %%
## langchain Model - Gemini API

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
## connecting google gemini model
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

res = llm.invoke("Which is the most aticipated metroidvaina game?")
res.content
# Out:
# d:\Generative AI\env\Lib\site-packages\langchain_core\utils\pydantic.py:41: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1
# "Splitsvilla 2026 has not happened yet!\n\nIt's currently 2024, so the season for 2026 would likely air in late 2025 or 2026. We'll have to wait a couple of years to find out who wins that season."

# %%
## connecting groq model
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant")
res = llm.invoke("What is context window in LLMs?")
res.content
# Out:
# "In Large Language Models (LLMs), a context window refers to the limited number of tokens or words that the model considers when generating a response or making predictions. It is also known as the context or input window size.\n\nThe context window determines how much of the input text or conversation history the model can see and process at a time. This is essential because processing the entire input text or conversation history can be computationally expensive and may require significant memory resources.\n\nWhen the context window is set to a certain size (e.g., 512 tokens), the model will only consider the tokens within that window when generating a response. If the input text exceeds the context window size, the model will use a combination of techniques such as:\n\n1. Tokenization: breaking down the input text into smaller tokens (e.g., words, subwords, or characters).\n2. Truncation: cutting off the input text at the end of the context window.\n3. Token shifting: moving the 
# ...

# %%
### Static Prompts

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.1-8b-instant")
prompts = [
    ###  two arguments bhejte hai (type , ) # "system" , "ai" , "user"
    ("system" , "You are a senior MERN developer") ,
      ("user" , "What are Reconciliation in React") 
]  
res = llm.invoke(prompts)
res
# Out:
# AIMessage(content='**Reconciliation in React**\n\nIn React, reconciliation is the process of comparing the virtual DOM (a lightweight in-memory representation of the UI) with the actual DOM and updating the UI accordingly. This process occurs whenever the state or props of a component change.\n\n**How Reconciliation Works**\n\nHere\'s a step-by-step explanation of the reconciliation process:\n\n1. **Update Detection**: When a component\'s state or props change, React updates the virtual DOM to reflect the new state.\n2. **Diffing**: React compares the updated virtual DOM with the actual DOM to determine which elements have changed.\n3. **Reconciliation**: React updates the actual DOM by creating, updating, or removing elements as necessary to match the updated virtual DOM.\n\n**Types of Reconciliation**\n\nThere are two types of reconciliation:\n\n1. **Element-level reconciliation**: This occurs when an element in the virtual DOM has changed. In this case, React will update the corre
# ...
